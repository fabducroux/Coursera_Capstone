# %% [markdown]
# # Report: The battle of the neighborhoods
#
# ## 1. Introduction
#
# ### 1.1 Background
#
# Montreal is the most populous municipality in the Canadian province of Quebec and the second-most populous municipality in Canada. Originally called Ville-Marie, or "City of Mary", it is named after Mount Royal, the triple-peaked hill in the heart of the city. The city is centred on the Island of Montreal, which took its name from the same source as the city. In 2016, the city had a population of 1,704,694, with a population of 1,942,044 in the urban agglomeration, including all of the other municipalities on the Island of Montreal. The broader metropolitan area had a population of 4,098,927. French is the city's official language and is the language spoken at home by 49.8% of the population of the city, followed by English at 22.8% and 18.3% other languages (in the 2016 census, not including multi-language responses).
#
# (Source: https://en.wikipedia.org/wiki/Montreal)
#
# ### 1.2 Problem
#
# By his diversity, Montreal is a place where some people speak English and other French. So, Neighborhoods are of different kind and it's difficult to know in which neighborhoods there is restaurants, shops or gym. This project aims to predict in which neighborhoods their are restaurants, bars, gyms or shops.
#
# ### 1.3 Interest
#
# People who are moving into the city needs to know if they are going to see more bars and nightclubs or more restaurants and shops. It's important to know where they're going.
#
# ## 2. Data acquisition
#
# ### 2.1 Data sources
#
# This dataset reports the Borough and Neighborhood in Montreal. Data is extracted from the Montreal City's website (http://donnees.ville.montreal.qc.ca/dataset/f38c91a1-e33f-4475-a112-3b84b1c60c1e/resource/a80e611f-5336-4306-ba2a-fd657f0f00fa/download/quartierreferencehabitation.geojson). It'll be use with the Foursquare API (www.foursquare.com) to know the venues through the neighborhood.
#
# ## 3. Analysis
# First of all, after all the steps of cleaning and sorting datas, we want to see the different neighborhood of the city of Montreal:
#
# ![2019-07-25%2011_24_12-IBM%20Watson%20Studio.png](attachment:2019-07-25%2011_24_12-IBM%20Watson%20Studio.png)
#
# There are a lot of neighborhood and we merge the datas of Montreal's neighborhood and the datas of the foursquare's API. After this, we have our map with the cluster!
#
# ![image.png](attachment:image.png)
#
# We can see the main venues of each neighborhoods:
#
# - Green: Restaurants
# - Red: Shops
# - Blue: Gym
# - Black: Liquor Store
# - Yellow: Construction & Landscape
#
# ## 4. Conclusion
#
# In this study, I analyzed the neighborhood of Montreal and the main venues in those. We had classified those neighborhood and we know, now, in which neighborhood we wanted to move in despite our interests.
#
# ## 5. Future directions
#
# We could add more datas, like the crime data and the social/economic data t
